# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
latency = pd.read_csv('./data/latency.csv')

# %%
latency
# Out:
#       Reno_DropTail_Time  Reno_DropTail_Value  Reno_RED_Time  Reno_RED_Value  \
# 0               0.030096               60.192       0.030096          60.192
# 1               0.091488               62.592       0.091488          62.592
# 2               0.091904               63.424       0.091904          63.424
# 3               0.154080               62.592       0.154080          62.592
# 4               0.154496               63.424       0.154496          63.424
# 5               0.155328               63.424       0.155328          63.424
# 6               0.155744               64.256       0.155744          64.256
# 7               0.216672               62.592       0.216672          62.592
# 8               0.217088               63.424       0.217088          63.424
# 9               0.217920               63.424       0.217920          63.424
# 10              0.218336               64.256       0.218336          64.256
# 11              0.219168               64.256       0.219168          64.256
# 12              0.219584               65.088       0.219584          65.088
# 13              0.220416               65.088       0.220416          65.088
# 14              0.220832               65.920       0.220832          65.920
# 15              0.279264               62.592       0.279264          62.592
# 16              0.279680               63.424       0.279680          63.424
# 17              0.280512               63.424       0.280512          63.424
# 18              0.280928               64.256       0.280928          64.256
# 19              0.281760               64.256       0.281760          64.256
# 20              0.282176               65.088       0.282176          65.088
# 21              0.283008               65.088       0.283008          65.088
# 22              0.283424               65.920       0.283424          65.920
# 23              0.284256               65.920       0.284256          65.920
# 24              0.284672               66.752       0.284672          66.752
# 25              0.285504               66.752       0.285504          66.752
# 26              0.285920               67.584       0.285920          67.584
# 27              0.286752               67.584       0.286752          67.584
# 28              0.287168               68.416       0.287168          68.416
# 29              0.288000               68.416       0.345184         182.784
# ...                  ...                  ...            ...             ...
# 4713                 NaN                  NaN            NaN             NaN
# 4714                 NaN                  NaN            NaN             NaN
# 4715                 NaN                  NaN            NaN             NaN
# 4716                 NaN                  NaN            NaN             NaN
# 4717                 NaN                  NaN            NaN             NaN
# 4718                 NaN                  NaN            NaN             NaN
# 4719                 NaN                  NaN            NaN             NaN
# 4720                 NaN                  NaN            NaN             NaN
# 4721                 NaN                  NaN            NaN             NaN
# 4722                 NaN                  NaN            NaN             NaN
# 4723                 NaN                  NaN            NaN             NaN
# 4724                 NaN                  NaN            NaN             NaN
# 4725                 NaN                  NaN            NaN             NaN
# 4726                 NaN                  NaN            NaN             NaN
# 4727                 NaN                  NaN            NaN             NaN
# 4728                 NaN                  NaN            NaN             NaN
# 4729                 NaN                  NaN            NaN             NaN
# 4730                 NaN                  NaN            NaN             NaN
# 4731                 NaN                  NaN            NaN             NaN
# 4732                 NaN                  NaN            NaN             NaN
# 4733                 NaN                  NaN            NaN             NaN
# 4734                 NaN                  NaN            NaN             NaN
# 4735                 NaN                  NaN            NaN             NaN
# 4736                 NaN                  NaN            NaN             NaN
# 4737                 NaN                  NaN            NaN             NaN
# 4738                 NaN                  NaN            NaN             NaN
# 4739                 NaN                  NaN            NaN             NaN
# 4740                 NaN                  NaN            NaN             NaN
# 4741                 NaN                  NaN            NaN             NaN
# 4742                 NaN                  NaN            NaN             NaN
#
#       SACK_DropTail_Time  SACK_DropTail_Value  SACK_RED_Time  SACK_RED_Value
# 0               0.030096               60.192       0.030096          60.192
# 1               0.091488               62.592       0.091488          62.592
# 2               0.091904               63.424       0.091904          63.424
# 3               0.154080               62.592       0.154080          62.592
# 4               0.154496               63.424       0.154496          63.424
# 5               0.155328               63.424       0.155328          63.424
# 6               0.155744               64.256       0.155744          64.256
# 7               0.216672               62.592       0.216672          62.592
# 8               0.217088               63.424       0.217088          63.424
# 9               0.217920               63.424       0.217920          63.424
# 10              0.218336               64.256       0.218336          64.256
# 11              0.219168               64.256       0.219168          64.256
# 12              0.219584               65.088       0.219584          65.088
# 13              0.220416               65.088       0.220416          65.088
# 14              0.220832               65.920       0.220832          65.920
# 15              0.279264               62.592       0.279264          62.592
# 16              0.279680               63.424       0.279680          63.424
# 17              0.280512               63.424       0.280512          63.424
# 18              0.280928               64.256       0.280928          64.256
# 19              0.281760               64.256       0.281760          64.256
# 20              0.282176               65.088       0.282176          65.088
# 21              0.283008               65.088       0.283008          65.088
# 22              0.283424               65.920       0.283424          65.920
# 23              0.284256               65.920       0.284256          65.920
# 24              0.284672               66.752       0.284672          66.752
# 25              0.285504               66.752       0.285504          66.752
# 26              0.285920               67.584       0.285920          67.584
# 27              0.286752               67.584       0.286752          67.584
# 28              0.287168               68.416       0.287168          68.416
# 29              0.288000               68.416       0.345222         182.861
# ...                  ...                  ...            ...             ...
# 4713            9.004717               62.592            NaN             NaN
# 4714            9.005549               62.592            NaN             NaN
# 4715            9.006381               62.592            NaN             NaN
# 4716            9.007213               62.592            NaN             NaN
# 4717            9.008045               62.592            NaN             NaN
# 4718            9.008877               62.592            NaN             NaN
# 4719            9.009709               62.592            NaN             NaN
# 4720            9.010541               62.592            NaN             NaN
# 4721            9.011373               62.592            NaN             NaN
# 4722            9.012205               62.592            NaN             NaN
# 4723            9.013037               62.592            NaN             NaN
# 4724            9.013453               63.424            NaN             NaN
# 4725            9.014285               63.424            NaN             NaN
# 4726            9.015117               63.424            NaN             NaN
# 4727            9.015949               63.424            NaN             NaN
# 4728            9.016781               63.424            NaN             NaN
# 4729            9.017853               62.944            NaN             NaN
# 4730            9.019309               62.592            NaN             NaN
# 4731            9.020941               62.592            NaN             NaN
# 4732            9.022573               62.592            NaN             NaN
# 4733            9.023405               62.592            NaN             NaN
# 4734            9.024237               62.592            NaN             NaN
# 4735            9.025069               62.592            NaN             NaN
# 4736            9.025901               62.592            NaN             NaN
# 4737            9.026733               62.592            NaN             NaN
# 4738            9.027565               62.592            NaN             NaN
# 4739            9.028397               62.592            NaN             NaN
# 4740            9.029229               62.592            NaN             NaN
# 4741            9.030061               62.592            NaN             NaN
# 4742            9.030893               62.592            NaN             NaN
#
# [4743 rows x 8 columns]

# %%
plt.plot(latency.Reno_DropTail_Time, latency.Reno_DropTail_Value)
plt.plot(latency.Reno_RED_Time, latency.Reno_RED_Value)
plt.plot(latency.SACK_DropTail_Time, latency.SACK_DropTail_Value)
plt.plot(latency.SACK_RED_Time, latency.SACK_RED_Value)
plt.title("Latency for Different Time Period")
plt.xlabel("Time in seconds")
plt.ylabel("Latency in ms")
plt.legend(["Reno DropTail", "Reno RED", "SACK DropTail", "SACK RED"])
plt.show()

# %%
throughput = pd.read_csv('./data/throughput.csv')

# %%
throughput
# Out:
#    Time  Reno_DropTail  Reno_RED  SACK_DropTail  SACK_RED
# 0   0.5          0.143     0.097          0.365     0.237
# 1   1.5          0.100     0.159          0.729     0.499
# 2   2.5          0.260     0.389          0.537     0.415
# 3   3.5          0.508     0.502          0.544     0.552
# 4   4.5          0.399     0.197          0.568     0.498
# 5   5.5          0.273     0.465          0.501     0.490
# 6   6.5          0.514     0.399          0.596     0.563
# 7   7.5          0.781     0.279          0.501     0.470
# 8   8.5          1.031     0.517          0.755     0.733
# 9   9.5          0.037     0.021          0.037     0.037

# %%
plt.plot(throughput.Time, throughput.Reno_DropTail)
plt.plot(throughput.Time, throughput.Reno_RED)
plt.plot(throughput.Time, throughput.SACK_DropTail)
plt.plot(throughput.Time, throughput.SACK_RED)
plt.title("Throughput for Different Time Period")
plt.xlabel("Time in seconds")
plt.ylabel("Mega Bytes")
plt.legend(["Reno DropTail", "Reno RED", "SACK DropTail", "SACK RED"])
plt.show()
